# %% [markdown]
# # Data processing
#
# ##Overview
#
# 1.   Import dependencies
# 2.   Mount drive and read in data
# 3.   Create a fasta file of all human paired data for processing by MMSeqs2
# 4.   Install Conda and MMSeqs2
# 5.   Run LinClust at 66% identity to obtain ~100K sequence clusters
# 6.   Transfer everthing to mmseqs_output folder on drive
#
# Data at this point will be converted into a csv file of heavy and light chains with unique identifiers for processing by Seb to obtain developability parameters using MAPT.

# %%
import os
from google.colab import drive
import polars as pl
import pandas as pd

# %%
#mount drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/msc-project-mbalmf01/'
# Out:
# Mounted at /content/drive

# %%
os.chdir(path)
os.mkdir('mmseqs2_output')

# %% [markdown]
# Read in all paired data

# %%
df = pl.read_csv('all_paired/opig_data/230618_human_paired_seqs.csv', dtypes={'Run': pl.Utf8})

# %%
print(df.columns)
print(df.head())
# Out:
# ['', 'sequence_id_heavy', 'ANARCI_status_heavy', 'sequence_heavy', 'sequence_alignment_aa_heavy', 'sequence_id_light', 'ANARCI_status_light', 'sequence_light', 'sequence_alignment_aa_light', 'Run', 'seq_id']
# shape: (5, 11)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬─────────┬─────────────┐
# │     ┆ sequence_i ┆ ANARCI_sta ┆ sequence_h ┆ … ┆ sequence_l ┆ sequence_a ┆ Run     ┆ seq_id      │
# │ --- ┆ d_heavy    ┆ tus_heavy  ┆ eavy       ┆   ┆ ight       ┆ lignment_a ┆ ---     ┆ ---         │
# │ i64 ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ a_light    ┆ str     ┆ str         │
# │     ┆ str        ┆ str        ┆ str        ┆   ┆ str        ┆ ---        ┆         ┆             │
# │     ┆            ┆            ┆            ┆   ┆            ┆ str        ┆         ┆             │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═════════╪═════════════╡
# │ 0   ┆ AAACCTGAGA ┆ |Deletions ┆ AGCTCTCAGA ┆ … ┆ GCTGTGCTGT ┆ SYELTQPPSV ┆ 1287185 ┆ AAACCTGAGAC │
# │     ┆ CTAAGT-1_c ┆ : 10,      ┆ GAGGTGCCTT ┆   ┆ GGGTCCAGGA ┆ SVSPGQTARI ┆         ┆ TAAGT-1_con │
# │     ┆ ontig_3    ┆ 73||||     ┆ AGCCCTGGAT ┆   ┆ GGCAGAACTC ┆ TCSGDALPKQ ┆         ┆ tig_3_AAAC… │
# │     ┆            ┆            ┆ TC…        ┆   ┆ TG…        ┆ YA…        ┆         ┆             │
# │ 1   ┆ AAACCTGAGA ┆ |Deletions ┆ TGGGGACCCA ┆ … ┆ AGAGCTCTGG ┆ EIVLTQSPGT ┆ 1287185 ┆ AAACCTGAGAG │
# │     ┆ GGGCTT-1_c ┆ : 10,      ┆ AAAACCACAC ┆   ┆ AGAAGAGCTG ┆ LSLSPGERAT ┆         ┆ GGCTT-1_con │
# │     ┆ ontig_1    ┆ 73||||     ┆ CCCTCCTTGG ┆   ┆ CTCAGTTAGG ┆ LSCRASQSVS ┆         ┆ tig_1_AAAC… │
# │     ┆            ┆            ┆ GA…        ┆   ┆ AC…        ┆ SS…        ┆         ┆             │
# │ 2   ┆ AAACCTGAGA ┆ |Deletions ┆ GCAGAGCCTG ┆ … ┆ CTGGGCCTCA ┆ SYELTQPPSV ┆ 1287185 ┆ AAACCTGAGAG │
# │     ┆ GTCTGG-1_c ┆ : 10,      ┆ CTGAATTCTG ┆   ┆ GGAAGCAGCA ┆ SVSPGQTASI ┆         ┆ TCTGG-1_con │
# │     ┆ ontig_1    ┆ 73||||     ┆ GCTGACCAGG ┆   ┆ TCGGAGGTGC ┆ TCSGDKLGDK ┆         ┆ tig_1_AAAC… │
# │     ┆            ┆            ┆ GC…        ┆   ┆ CT…        ┆ YA…        ┆         ┆             │
# │ 3   ┆ AAACCTGAGC ┆ |Deletions ┆ AGCTCTGAGA ┆ … ┆ CTGGGCCTCA ┆ SYELTQPPSV ┆ 1287185 ┆ AAACCTGAGCG │
# │     ┆ GTAATA-1_c ┆ : 10,      ┆ GAGGAGCCCA ┆   ┆ GGAAGCAGCA ┆ SVSPGQTASI ┆         ┆ TAATA-1_con │
# │     ┆ ontig_2    ┆ 73||||     ┆ GCCCTGGGAT ┆   ┆ TCGGAGGTGC ┆ TCSGDKLGDK ┆         ┆ tig_2_AAAC… │
# │     ┆            ┆            ┆ TT…        ┆   ┆ CT…        ┆ YA…        ┆         ┆             │
# │ 4   ┆ AAACCTGAGC ┆ |Deletions ┆ GAGAGAGGAG ┆ … ┆ AGAGCTCTGG ┆ EIVLTQSPGT ┆ 1287185 ┆ AAACCTGAGCT │
# │     ┆ TAACAA-1_c ┆ : 10,      ┆ CCCAGCCCTG ┆   ┆ AGAAGAGCTG ┆ LSLSPGERAT ┆         ┆ AACAA-1_con │
# │     ┆ ontig_2    ┆ 73||||     ┆ GGATTTTCAG ┆   ┆ CTCAGTTAGG ┆ LSCRASQSVS ┆         ┆ tig_2_AAAC… │
# │     ┆            ┆            ┆ GT…        ┆   ┆ AC…        ┆ SS…        ┆         ┆             │
# └─────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴─────────┴─────────────┘

# %%
def df_to_fasta(df: pd, cols: list, f: str):
    x = cols[0]
    y = cols[1]
    with open(f, 'w') as out:
        for i in range(df.shape[0]):
            out.write('>' + df[x].iloc[i] + '\n' + df[y].iloc[i] + '\n')

# %%
interspacing_string = pl.lit('SGGSTITSYNVYYTKLSSSGT')
df = df.with_columns(
    pl.concat_str([pl.col('sequence_alignment_aa_heavy'), interspacing_string, pl.col('sequence_alignment_aa_light')]).alias('heavy_light')
)

df_sub = df.to_pandas()[['seq_id', 'heavy_light']]

# %%
df_to_fasta(df_sub, ['seq_id', 'heavy_light'], 'all_paired/paired_human.fasta')

# %% [markdown]
# Run commands to install conda, mmseqs2

# %%
#append site-packages to path to run conda/mmseqs2/cd-hit
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !bash ./Miniconda3-py39_23.3.1-0-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2023-06-20 20:57:59--  https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70605094 (67M) [application/x-sh]
# Saving to: ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh.1’
#
# Miniconda3-py39_23. 100%[===================>]  67.33M  30.6MB/s    in 2.2s
#
# 2023-06-20 20:58:01 (30.6 MB/s) - ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh.1’ saved [70605094/70605094]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages
#
#
# Downloading and Extracting Packages
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# install via conda
# !conda install -c conda-forge -c bioconda mmseqs2
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mmseqs2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     conda-23.5.0               |   py39hf3d152e_1         994 KB  conda-forge
#     gawk-5.1.0                 |       h7f98852_0         1.4 MB  conda-forge
#     libidn2-2.3.4              |       h5eee18b_0         146 KB
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     mmseqs2-13.45111           |       h95f258a_1         2.1 MB  bioconda
#     openssl-1.1.1u             |       h7f8727e_0         3.7 MB
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     wget-1.20.3                |       ha56f1ee_1         804 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   gawk               conda-forge/linux-64::gawk-5.1.0-h7f98852_0
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   mmseqs2            bioconda/linux-64::mmseqs2-13.45111-h95f258a_1
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#   wget               conda-forge/linux-64::wget-1.20.3-ha56f1ee_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-hbcca054_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-23.3.1-py39h06a4308_0 --> conda-forge::conda-23.5.0-py39hf3d152e_1
#   openssl                                 1.1.1t-h7f8727e_0 --> 1.1.1u-h7f8727e_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# libunistring-0.9.10  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
# certifi-2023.5.7     | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# mmseqs2-13.45111     | 2.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# conda-23.5.0         | 994 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ca-certificates-2023 | 145 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# openssl-1.1.1u       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# python_abi-3.9       | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libidn2-2.3.4        | 146 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# wget-1.20.3          | 804 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# gawk-5.1.0           | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 484 KB    | :   0% 0/1 [00:00<?, ?it/s]
# libunistring-0.9.10  | 1.4 MB    | :   1% 0.011429878976110548/1 [00:00<00:10, 10.94s/it]
#
#
#
# ca-certificates-2023 | 145 KB    | :  11% 0.1104340792666487/1 [00:00<00:00,  1.05s/it]
#
#
# conda-23.5.0         | 994 KB    | :   2% 0.016095693930320107/1 [00:00<00:08,  9.01s/it]
#
# mmseqs2-13.45111     | 2.1 MB    | :   1% 0.007572994767219619/1 [00:00<00:20, 20.27s/it]
#
#
#
#
#
# python_abi-3.9       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  5.06it/s]
#
#
#
# libunistring-0.9.10  | 1.4 MB    | :  95% 0.9486799550171755/1 [00:00<00:00,  4.88it/s]
#
#
#
# ca-certificates-2023 | 145 KB    | : 100% 1.0/1 [00:00<00:00,  5.30it/s]
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
#
# mmseqs2-13.45111     | 2.1 MB    | :  67% 0.6739965342825461/1 [00:00<00:00,  3.23it/s]
#
#
#
#
# openssl-1.1.1u       | 3.7 MB    | :   0% 0.004220937643787281/1 [00:00<01:00, 60.29s/it]
#
#
#
#
#
# python_abi-3.9       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  5.06it/s]
#
#
#
#
#
#
#
#
# gawk-5.1.0           | 1.4 MB    | :   1% 0.01129395155953589/1 [00:00<00:25, 25.57s/it]
#
#
#
#
#
#
#
# wget-1.20.3          | 804 KB    | :   2% 0.019893296939997133/1 [00:00<00:14, 14.87s/it]
#
#
#
#
#
#
# libidn2-2.3.4        | 146 KB    | :  11% 0.10992726979952229/1 [00:00<00:02,  2.73s/it]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 484 KB    | :   3% 0.03305318286173101/1 [00:00<00:09,  9.59s/it]
#
#
#
#
# openssl-1.1.1u       | 3.7 MB    | :  33% 0.33345407385919523/1 [00:00<00:00,  1.19it/s]
#
#
# conda-23.5.0         | 994 KB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  4.88it/s]
#
#
#
#
#
#
# libidn2-2.3.4        | 146 KB    | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
# libidn2-2.3.4        | 146 KB    | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 484 KB    | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 484 KB    | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
# mmseqs2-13.45111     | 2.1 MB    | : 100% 1.0/1 [00:01<00:00,  3.23it/s]
#
#
#
#
#
#
#
# wget-1.20.3          | 804 KB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
#
#
#
#
#
#
#
# wget-1.20.3          | 804 KB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
#
#
#
#
# openssl-1.1.1u       | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
# openssl-1.1.1u       | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
# gawk-5.1.0           | 1.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# OS to /tmp and create a new directory to run linclust algorithm in

# %%
os.chdir('/tmp')
# !mkdir /tmp/new_tmp
# !cp /content/drive/MyDrive/msc-project-mbalmf01/all_paired/paired_human.fasta /tmp

# %% [markdown]
# Run the MMSeqs2 easy-linclust program on the antibody sequences at 67% similarity to reduce number down to ~100,000 representative sequences. I tried a bunch of different values here: 0.8, 0.75, 0.7, 0.6, 0.65 and finally 0.67.
#
# This may take a while ~45 mins to run. The larger the cutoff the longer it takes..

# %%
# !sudo mmseqs easy-linclust paired_human.fasta clusterRes new_tmp --min-seq-id 0.66 -c 0.8 --cov-mode 1
# Out:
# easy-linclust paired_human.fasta clusterRes new_tmp --min-seq-id 0.67 -c 0.8 --cov-mode 1
#
# MMseqs Version:                     	13.45111
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Threads                             	2
# Compressed                          	0
# Verbosity                           	3
# Substitution matrix                 	nucl:nucleotide.out,aa:blosum62.out
# Add backtrace                       	false
# Alignment mode                      	0
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.67
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Coverage threshold                  	0.8
# Coverage mode                       	1
# Max sequence length                 	65535
# Compositional bias                  	1
# Max reject                          	2147483647
# Max accept                          	2147483647
# Include identical seq. id.          	false
# Preload mode                        	0
# Pseudo count a                      	1
# Pseudo count b                      	1.5
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Gap open cost                       	nucl:5,aa:11
# Gap extension cost                  	nucl:2,aa:1
# Zdrop                               	40
# Alphabet size                       	nucl:5,aa:21
# k-mers per sequence                 	21
# Spaced k-mers                       	0
# Spaced k-mer pattern
# Scale k-mers per sequence           	nucl:0.200,aa:0.000
# Adjust k-mer length                 	false
# Mask residues                       	1
# Mask lower case residues            	0
# k-mer length                        	0
# Shift hash                          	67
# Split memory limit                  	0
# Include only extendable             	false
# Skip repeating k-mers               	false
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
#
# createdb paired_human.fasta new_tmp/10267054346655741156/input --dbtype 0 --shuffle 1 --createdb-mode 1 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Shuffle database cannot be combined with --createdb-mode 0
# We recompute with --shuffle 0
# Converting sequences
# [1409254] 1s 915ms
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 916ms
# Create directory new_tmp/10267054346655741156/clu_tmp
# linclust new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu new_tmp/10267054346655741156/clu_tmp -e 0.001 --min-seq-id 0.67 -c 0.8 --cov-mode 1 --spaced-kmer-mode 0 --remove-tmp-files 1
#
# Set cluster mode GREEDY MEM.
# kmermatcher new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.67 --kmer-per-seq 21 --spaced-kmer-mode 0 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3
#
# kmermatcher new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.67 --kmer-per-seq 21 --spaced-kmer-mode 0 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3
#
# Database size: 1409295 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 1.41M 17s 512ms
# Sort kmer 0h 0m 10s 290ms
# Sort by rep. sequence 0h 0m 3s 868ms
# Time for fill: 0h 0m 1s 792ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 38s 404ms
# rescorediagonal new_tmp/10267054346655741156/input new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore1 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.67 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 1.41M 11s 143ms
# Time for merging to pref_rescore1: 0h 0m 0s 870ms
# Time for processing: 0h 0m 12s 764ms
# clust new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore1 new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 724ms
#
# Size of the sequence database: 1409295
# Size of the alignment database: 1409295
# Number of clusters: 1278359
#
# Writing results 0h 0m 0s 229ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 517ms
# createsubdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/order_redundancy new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 337ms
# createsubdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/order_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 621ms
# filterdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter1 new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter2 --filter-file new_tmp/10267054346655741156/clu_tmp/16123882020536940103/order_redundancy --threads 2 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 1.28M 6s 253ms
# Time for merging to pref_filter2: 0h 0m 0s 490ms
# Time for processing: 0h 0m 7s 560ms
# rescorediagonal new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter2 new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore2 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.67 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 1.28M 15s 238ms
# Time for merging to pref_rescore2: 0h 0m 0s 493ms
# Time for processing: 0h 0m 16s 142ms
# align new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore2 new_tmp/10267054346655741156/clu_tmp/16123882020536940103/aln --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 2 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.67 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score and coverage
# Query database size: 1278359 type: Aminoacid
# Target database size: 1278359 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 1.28M 37m 3s 184ms
# Time for merging to aln: 0h 0m 0s 822ms
# 12405754 alignments calculated
# 4424690 sequence pairs passed the thresholds (0.356664 of overall calculated)
# 3.461226 hits per query sequence
# Time for processing: 0h 37m 4s 517ms
# clust new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy new_tmp/10267054346655741156/clu_tmp/16123882020536940103/aln new_tmp/10267054346655741156/clu_tmp/16123882020536940103/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 3s 115ms
#
# Size of the sequence database: 1278359
# Size of the alignment database: 1278359
# Number of clusters: 111158
#
# Writing results 0h 0m 0s 51ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 3s 712ms
# mergeclusters new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pre_clust new_tmp/10267054346655741156/clu_tmp/16123882020536940103/clust --threads 2 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 1.28M 0s 362ms
# Clustering step 2
# [=================================================================] 100.00% 111.16K 0s 842ms
# Write merged clustering
# [=================================================================] 100.00% 1.41M 1s 103ms
# Time for merging to clu: 0h 0m 0s 33ms
# Time for processing: 0h 0m 1s 805ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref -v 3
#
# Time for processing: 0h 0m 0s 23ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 8ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 4ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 29ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 31ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/aln -v 3
#
# Time for processing: 0h 0m 0s 44ms
# rmdb new_tmp/10267054346655741156/clu_tmp/16123882020536940103/clust -v 3
#
# Time for processing: 0h 0m 0s 2ms
# createtsv new_tmp/10267054346655741156/input new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu new_tmp/10267054346655741156/cluster.tsv --threads 2 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 1s 993ms
# Time for processing: 0h 0m 4s 216ms
# result2repseq new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu new_tmp/10267054346655741156/clu_rep --db-load-mode 0 --compressed 0 --threads 2 -v 3
#
# [=================================================================] 100.00% 111.16K 0s 128ms
# Time for merging to clu_rep: 0h 0m 0s 134ms
# Time for processing: 0h 0m 0s 646ms
# result2flat new_tmp/10267054346655741156/input new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_rep new_tmp/10267054346655741156/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 963ms
# createseqfiledb new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu new_tmp/10267054346655741156/clu_seqs --threads 2 -v 3
#
# [=================================================================] 100.00% 111.16K 6s 938ms
# Time for merging to clu_seqs: 0h 0m 0s 155ms
# Time for processing: 0h 0m 8s 313ms
# result2flat new_tmp/10267054346655741156/input new_tmp/10267054346655741156/input new_tmp/10267054346655741156/clu_seqs new_tmp/10267054346655741156/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 6s 550ms
# rmdb new_tmp/10267054346655741156/input -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb new_tmp/10267054346655741156/input_h -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb new_tmp/10267054346655741156/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 120ms
# rmdb new_tmp/10267054346655741156/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 8ms
# rmdb new_tmp/10267054346655741156/clu -v 3
#
# Time for processing: 0h 0m 0s 1ms

# %% [markdown]
# Copy all files over from /tmp to mmseqs2_output folder

# %%
# !mv /tmp/clusterRes_all_seqs.fasta /content/drive/MyDrive/msc-project-mbalmf01/mmseqs2_output
# !mv /tmp/clusterRes_cluster.tsv /content/drive/MyDrive/msc-project-mbalmf01/mmseqs2_output
# !mv /tmp/clusterRes_rep_seq.fasta /content/drive/MyDrive/msc-project-mbalmf01/mmseqs2_output

# !cp -R /tmp/new_tmp /content/drive/MyDrive/msc-project-mbalmf01/mmseqs2_output
