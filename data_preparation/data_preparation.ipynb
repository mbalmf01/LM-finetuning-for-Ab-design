# %% [markdown]
# # Data extraction and preparation
#
# ## Overview
# 1.   Pull paired sequence data from opig
# 2.   Import dependencies
# 3.   Transfer pulled data to a new directory in Google Drive
# 4.   Read sequence data into a polars dataframe and concatenate
# 5. Save data to Drive

# %% [markdown]
# ## Pull paired sequence data from opig
#
# Use wget command to pull data from https://opig.stats.ox.ac.uk/webapps/oas/oas_paired. Expected number of sequences is 1,572,406 filtered sequences from 8 studies.

# %%
# @title Pull data from OPIG with wget { display-mode: "form" }
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875351_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875354_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875355_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875359_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875356_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875349_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875353_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875362_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875357_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875360_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875361_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875352_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875350_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875358_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Mor_2021/csv/SRR12875348_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Setliff_2019/csv/SRR10313332_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Setliff_2019/csv/SRR10313335_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Woodruff_2020/csv/SRR12113363_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Woodruff_2020/csv/SRR12113364_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179273_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179279_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179277_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179287_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179281_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179288_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179295_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179276_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179300_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179299_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179298_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179280_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179292_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179285_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179283_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179274_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179289_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179278_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179297_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179291_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179293_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179275_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179290_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179284_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179294_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179296_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179282_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Goldstein_2019/csv/SRR9179286_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Alsoiussi_2020/csv/SRR11528761_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Alsoiussi_2020/csv/SRR11528762_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Eccles_2020/csv/SRR10358523_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Eccles_2020/csv/SRR10358524_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Eccles_2020/csv/SRR10358525_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279050_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287176_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287206_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279076_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287192_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287193_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287156_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279075_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279059_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287195_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279066_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287185_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287163_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287180_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287146_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279080_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279060_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279073_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287191_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279062_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287147_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287179_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279070_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287203_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287151_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287175_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287150_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287172_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287201_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287167_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287145_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287204_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287161_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287152_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287157_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287169_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287197_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287207_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287194_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287155_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287205_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279067_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287182_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287184_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287189_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279071_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279065_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279078_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287159_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279051_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279053_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287168_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279058_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279079_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287190_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287153_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287170_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287198_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279074_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287166_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287160_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287196_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287158_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287199_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287171_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279068_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287200_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287173_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287181_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279072_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287187_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287154_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279055_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287183_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287162_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287178_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287164_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279052_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287174_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279061_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279054_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279069_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279049_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279077_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287186_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279063_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287144_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287188_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287202_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287177_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1279057_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287149_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287165_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/Jaffe_2022/csv/1287148_1_Paired_All.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082299_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082251_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082263_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082243_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082283_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082275_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082259_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082303_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082235_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082227_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082267_paired.csv.gz" >> wget_commands.txt
# !echo "http://opig.stats.ox.ac.uk/webapps/ngsdb/paired/King_2020_2/csv/ERR4082291_paired.csv.gz" >> wget_commands.txt

# !mkdir /content/all_paired
# !mkdir /content/all_paired/opig_data
# !wget -P /content/all_paired/opig_data -i wget_commands.txt

# %%
#@title Install and import dependencies { display-mode: "form" }
# %%capture
# !pip install polars
# !pip install biopython

import polars as pl, pandas as pd
import gzip, os, json
import pprint as pp

# %% [markdown]
# # Unzip csv files and extract data
#
# *   Read metadata and use to filter out non-human sequences
# *   Create a Run identifier column from metadata
# *   Create a unique paired antibody identifier by concatenating heavy chain ID, light chain ID and Run identifier
# *   Force unique identifier by adding '_1' to any duplicated identifiers

# %%
#@title Unzip csv files, read metadata and store in

os.chdir('/content/all_paired/opig_data')
files = os.listdir()

l = []
for filey in files:
  if 'csv.gz' in filey:
    #filey = files[1]
    with gzip.open(filey, 'rb') as f:
      #extract metadata and save as a dictionary
      metadata = f.readline()
      metadata = metadata.decode()
      metadata = metadata.strip().strip('"').replace('""', '"')
      metadata = json.loads(metadata)

    if metadata['Species'] == 'human':
      with gzip.open(filey, 'rb') as fs:
        # #read in antibody data and keep id, dna, and protein sequences
        df = pl.read_csv(fs, skip_rows=1)
        df = df[['sequence_id_heavy', 'ANARCI_status_heavy', 'sequence_heavy', 'sequence_alignment_aa_heavy', 'v_call_heavy', 'd_call_heavy', 'j_call_heavy', 'sequence_id_light', 'ANARCI_status_light', 'sequence_light', 'v_call_light', 'j_call_light', 'sequence_alignment_aa_light']]
        #add a column using the metadata key
        Run = pl.Series([metadata['Run']]*df.shape[0]).alias('Run')
        # Add the new column to the DataFrame
        df = df.with_columns(Run)
        #save the dataframe to a list
        l.append(df)

l = [i.with_columns(pl.col('Run').cast(pl.Utf8)) for i in l]

df = pl.concat(l)

df = df.with_columns(
    pl.concat_str([
        pl.col('sequence_id_heavy'),
        pl.lit('_'),
        pl.col('sequence_id_light'),
        pl.lit('_'),
        pl.col('Run')
    ]).alias('seq_id')
)

# #having to get rid of duplicated seq IDs by adding '_1' to every duplicated sequence
df = df.to_pandas()
df['Run'] = df['Run'].astype(str)
duplicated_mask = df['seq_id'].duplicated()

df['seq_id'] = df.apply(lambda row: row['seq_id'] + '_1' if duplicated_mask[row.name] else row['seq_id'], axis=1)

# %% [markdown]
# ANARCI status carries sequence quality control. If ANARCI flags a sequence as displaying a framework shorter than the IMGT numbering and definition, that indicates that the sequence is truncated and not useful for downstream modelling. These sequences will be removed from the dataset by filtering out any sequences flagged as containing deletions beyond the standard 10,73 notation.

# %%
df['ANARCI_status_heavy'].value_counts()
# Out:
# |Deletions: 10, 73||||                                            1462363
# |Deletions: 1, 10, 73|||Shorter than IMGT defined: fw1|              7902
# |Deletions: 10, 73, 128|||Shorter than IMGT defined: fw4|            7597
# |Deletions: 1, 2, 10, 73|||Shorter than IMGT defined: fw1|           4733
# |Deletions: 10, 73, 127, 128|||Shorter than IMGT defined: fw4|        978
#                                                                    ...
# |Deletions: 10, 73|Insertion: V82A, T82B, T82C, D82D, D82E|||           1
# |Deletions: 10, 73, 84|Insertion: P68A, T68B|||                         1
# |Deletions: 10, 73|Insertion: T81A, S81B, S81C, V81D, D81E|||           1
# |Deletions: 10, 73|Insertion: G16A, V16B, Q16C, P16D, W16E|||           1
# |Deletions: 10, 73|Insertion: D80A, T80B, S80C, S80D, V80E|||           1
# Name: ANARCI_status_heavy, Length: 890, dtype: int64

# %%
df['ANARCI_status_light'].value_counts()
# Out:
# |||||                                                                                     1432821
# ||||Shorter than IMGT defined: fw4|                                                         39011
# ||||Shorter than IMGT defined: fw1|                                                         15015
# ||||Shorter than IMGT defined: fw1, fw4|                                                     2041
# |||Missing Conserved Cysteine: 23||                                                           101
#                                                                                            ...
# ||Insertion: N82A, T82B, A82C, T82D, L82E|||                                                    1
# ||Insertion: Q44A, R44B|||                                                                      1
# ||Insertion: K47A, A47B, P47C, K47D, P47E, G47F||Shorter than IMGT defined: fw4|                1
# ||Insertion: T82A, Y82B, F82C, T82D, L82E, T82F, G82G||Shorter than IMGT defined: fw4|          1
# ...

# %%
df = df[~df['ANARCI_status_heavy'].str.contains('Shorter')]
df = df[df['ANARCI_status_light'].str.contains('Shorter')]
df.shape
# Out:
# (1409295, 15)

# %%
df.to_csv('/content/drive/MyDrive/msc-project-mbalmf01/all_paired/230625_human_paired_seqs.csv')
